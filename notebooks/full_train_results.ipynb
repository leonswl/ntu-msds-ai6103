# %% [markdown]
# ## Training Results
#
# Datasets:
# - R8
# - mr
# - ohsumed
#
# Configs:
# - epochs: 1000
# - early stop: 300

# %%
import os
import pickle as pkl
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utility import clean_metrics_df, load_results, plot_train_results

# %% [markdown]
# ## Dataset: R8

# %%
r8_loss_res, r8_acc_res = load_results(run_id='1000_epochs')

# %%
# r8_loss_df = reset_index_df(df=r8_loss_res)
# r8_acc_df = reset_index_df(df=r8_acc_res)

r8_loss_df, r8_acc_df = clean_metrics_df(r8_loss_res, r8_acc_res)

# %%
mr_fig = plot_train_results(
    loss_df=r8_loss_df,
    acc_df=r8_acc_df,
    dataset='r8',
    ylabel=True,
    title=True,
    savefig=True
)

# %% [markdown]
# ## Dataset: mr

# %%
mr_loss_res, mr_acc_res = load_results(run_id='run_2024-04-21_11-55-11')

# %%
mr_loss_df, mr_acc_df = clean_metrics_df(mr_loss_res, mr_acc_res)

# %%
mr_fig = plot_train_results(
    loss_df=mr_loss_df,
    acc_df=mr_acc_df,
    dataset='mr',
    ylabel=True,
    title=True,
    savefig=True
)

# %% [markdown]
# ## Dataset: ohsumed

# %%
ohsumed_loss_res, ohsumed_acc_res = load_results(run_id='run_2024-04-21_14-21-10')

# %%
ohsumed_loss_df, ohsumed_acc_df = clean_metrics_df(ohsumed_loss_res, ohsumed_acc_res)

# %%
ohsumed_fig = plot_train_results(
    loss_df=ohsumed_loss_df,
    acc_df=ohsumed_acc_df,
    dataset='ohsumed',
    ylabel=True,
    title=True,
    savefig=True
)

# %%
r8_acc_df.tail()
# Out:
#      epoch  train_acc  valid_acc  test_acc
# 804    805   0.847883   0.921533  0.952490
# 805    806   0.861049   0.917883  0.952033
# 806    807   0.865708   0.917883  0.951576
# 807    808   0.830059   0.917883  0.951576
# 808    809   0.852542   0.917883  0.951576

# %%
mr_acc_df.tail()
# Out:
#      epoch  train_acc  valid_acc  test_acc
# 386    387   0.605658   0.735211  0.715813
# 387    388   0.624258   0.735211  0.711593
# 388    389   0.614411   0.730986  0.705965
# 389    390   0.619881   0.722535  0.702307
# 390    391   0.622851   0.719718  0.699775
